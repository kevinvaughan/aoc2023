# %%
with open("../input.txt") as f:
    input = [line.strip() for line in f.readlines()]
# print(input)

with open("sample-input.txt") as f:
    sample_input = [line.strip() for line in f.readlines()]
print(f"Input: {sample_input}")
# Out:
# Input: ['FF7FSF7F7F7F7F7F---7', 'L|LJ||||||||||||F--J', 'FL-7LJLJ||||||LJL-77', 'F--JF--7||LJLJ7F7FJ-', 'L---JF-JLJ.||-FJLJJ7', '|F|F-JF---7F7-L7L|7|', '|FFJF7L7F-JF7|JL---7', '7-L-JL7||F7|L7F-7F7|', 'L.L7LFJ|||||FJL7||LJ', 'L7JLJL-JLJLJL--JLJ.L']

# %%
import numpy as np

# tile mask
tile_mask = {
    '|' : 0b001,
    '-' : 0b010,
    'L' : 0b011,
    'J' : 0b100,
    '7' : 0b101,
    'F' : 0b110,
    'S' : 0b111,
    '.' : 0b000,
}
def tile_from_mask(mask):
    for k, v in tile_mask.items():
        if v == mask:
            return k
    return '?'

neighbor_masks = {
    tile_mask['|'] : np.array([[0, 1, 0], [0, 0, 0], [0, 1, 0]]), # up and down
    tile_mask['-'] : np.array([[0, 0, 0], [1, 0, 1], [0, 0, 0]]), # left and right
    tile_mask['L'] : np.array([[0, 1, 0], [0, 0, 1], [0, 0, 0]]), # right and up
    tile_mask['J'] : np.array([[0, 1, 0], [1, 0, 0], [0, 0, 0]]), # left and up
    tile_mask['7'] : np.array([[0, 0, 0], [1, 0, 0], [0, 1, 0]]), # left and down
    tile_mask['F'] : np.array([[0, 0, 0], [0, 0, 1], [0, 1, 0]]), # right and down
    tile_mask['S'] : np.array([[0, 1, 0], [1, 0, 1], [0, 1, 0]]), # all
}

# %%
src = input.copy()

def get_valid_neighbors(row, col, grid):
    # Get the 3x3 neighborhood
    neighborhood = grid[row-1:row+2, col-1:col+2]
    mask = neighbor_masks[grid[row, col]]
    return np.argwhere((neighborhood * mask) > 0) - 1 + [row, col]

def update_distances(grid, dist_grid, curr_dist):
    rows, cols = np.where(dist_grid == curr_dist)
    for row, col in zip(rows, cols):
        neighbors = get_valid_neighbors(row, col, grid)
        for n_row, n_col in neighbors:
            if np.isnan(dist_grid[n_row, n_col]):
                dist_grid[n_row, n_col] = curr_dist + 1

grid = np.array([list(row) for row in src])
mask_grid = np.vectorize(tile_mask.get)(grid)
padded_mask_grid = np.pad(mask_grid, pad_width=1, mode='constant', constant_values=0)

# Initialize distance grid
dist_grid = np.full_like(padded_mask_grid, np.nan, dtype=float)
start_pos = np.argwhere(padded_mask_grid == tile_mask['S'])[0]
curr_dist = 0
dist_grid[tuple(start_pos)] = curr_dist

# check cardinals from start_pos for matching neighbors THAT RECIPROCATE.
# Specification guarantees we only have to care about this once.
neighbors = get_valid_neighbors(*start_pos, padded_mask_grid)
curr_dist += 1
for n_row, n_col in neighbors:
    if np.all(np.any(get_valid_neighbors(n_row, n_col, padded_mask_grid) == start_pos, axis=0)):
        dist_grid[n_row, n_col] = curr_dist

while np.any(np.isnan(dist_grid)) and np.any(dist_grid == curr_dist):
    update_distances(padded_mask_grid, dist_grid, curr_dist)
    curr_dist += 1

# print(dist_grid)

# %%
# Replace the ambiguous S with the correct pipe shape based on the connected pipes, for flood filling the right way
start_neighborhood = dist_grid.copy()[start_pos[0]-1:start_pos[0]+2, start_pos[1]-1:start_pos[1]+2].astype(int)

print("Before:\n", grid[start_pos[0] - 2:start_pos[0] + 1, start_pos[1] - 2:start_pos[1] + 1])

start_neighborhood[start_neighborhood != 1] = 0
for k, v in neighbor_masks.items():
    if np.array_equal(start_neighborhood & v, v):
        start_letter = tile_from_mask(k)
        break
grid[start_pos[0] - 1, start_pos[1] - 1] = start_letter

print("After:\n", grid[start_pos[0] - 2:start_pos[0] + 1, start_pos[1] - 2:start_pos[1] + 1])
# Out:
# Before:
#  [['J' '|' '|']
#  ['7' 'S' 'J']
#  ['J' 'F' '-']]
# After:
#  [['J' '|' '|']
#  ['7' 'L' 'J']
#  ['J' 'F' '-']]

# %%
def create_expanded_grid(fill_grid):
    rows, cols = fill_grid.shape
    expanded_fill_grid = np.full((rows * 2 - 1, cols), ' ', dtype=str)
    expanded_fill_grid[::2] = fill_grid
    return expanded_fill_grid

def update_vertical_connections(expanded_fill_grid):
    for i in range(1, len(expanded_fill_grid), 2):
        row_above = expanded_fill_grid[i - 1]
        row_below = expanded_fill_grid[i + 1] if i + 1 < len(expanded_fill_grid) else None
        connections = np.isin(row_above, ['F', '7', '|']) & np.isin(row_below, ['L', 'J', '|'])
        expanded_fill_grid[i][connections] = '|'
    return expanded_fill_grid

def expand_horizontal(expanded_fill_grid):
    rows, cols = expanded_fill_grid.shape
    horizontal_expanded_grid = np.full((rows, cols * 2 - 1), ' ', dtype=str)
    horizontal_expanded_grid[:, ::2] = expanded_fill_grid
    return horizontal_expanded_grid

def update_horizontal_connections(horizontal_expanded_grid):
    rows, cols = horizontal_expanded_grid.shape
    for i in range(rows):
        for j in range(1, cols, 2):
            col_left = horizontal_expanded_grid[i, j - 1]
            col_right = horizontal_expanded_grid[i, j + 1] if j + 1 < cols else None
            if col_left in ['F', 'L', '-'] and col_right in ['J', '7', '-']:
                horizontal_expanded_grid[i, j] = '-'
    return horizontal_expanded_grid

def flood_fill(grid, x, y, target, replacement):
    stack = [(x, y)]
    while stack:
        x, y = stack.pop()
        if 0 <= x < grid.shape[0] and 0 <= y < grid.shape[1] and grid[x, y] == target:
            grid[x, y] = replacement
            stack.extend([(x + 1, y), (x - 1, y), (x, y + 1), (x, y - 1)])

fill_grid = np.where(~np.isnan(dist_grid), np.pad(grid, pad_width=1, mode='constant', constant_values=' '), ' ')

# Stretch vertically and expand vertical connections with pipes
expanded_fill_grid = create_expanded_grid(fill_grid)
expanded_fill_grid = update_vertical_connections(expanded_fill_grid)

# Stretch horizontally and expand horizontal connections with bars
horizontal_expanded_grid = expand_horizontal(expanded_fill_grid)
horizontal_expanded_grid = update_horizontal_connections(horizontal_expanded_grid)

# Wash, fill, cut, and dry
horizontal_expanded_grid[horizontal_expanded_grid == '.'] = ' '
flood_fill(horizontal_expanded_grid, 0, 0, ' ', 'O')
final_grid = horizontal_expanded_grid[::2, ::2][1:-1, 1:-1]

print(f"Enclosed: {np.count_nonzero(final_grid == ' ')}")
print("\n".join([''.join(row) for row in final_grid]))
# Out:
# Enclosed: 595
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF7OF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF7OOF7FJL7||F7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF-7||F7|||F-J|LJL-7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOF7OF7F7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOF7OOOOOOOOOOOOOOL7LJ|||||||F7|F---JOOOOOF7F7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOF7OOOF7||O||||OOOOOOOOOOOOOOOOOOOOOOOOOOOOFJL-7OOOOOOOOOOOOOL-7LJLJ||||LJL7OF7OOOOFJLJL7OF7OOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOF7||OF7|||L7|LJL--7OOOOOOOOOOOOOOOOOOOOOOOOOL7F-JOOOOOOOOOOOOOF-JF-7FJ||L7F-JFJL7OF7L-7F7L-JL-7OOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOFJ||L-J||LJFJ|F7F--JOF7OOOOOOOOOOOOOOOOOOOOOF-JL-7F7OOOOOOOOOOOL--JO|L-J|FJL7FJF-JFJL--J|L--7F-JOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOL7LJF7FJL-7L7||LJF7OO||OOOOOOOOF7OF7OOOOOF7OL---7||L-7OOOOOOOOOF--7FJF--J|F-JL7L-7L----7|F7OLJF7OOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOL7FJLJF-7L7LJ|F-JL7O|L7OOF7OOFJ|FJL7OOOO||F-7F7|||F-JF7F7OOOOOL-7|L7L-7FJ|F7FJF-JF7F7FJLJL7OFJL-7OOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOF--J|F7OL7L7|F-JL7F7L7L7|F7||OFJFJ|F-JOF7O||L7||LJLJ|F7|LJL7F7F7F7||FJF-JL7|||L7|F-J|||L7F--JFJF-7|OOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOL--7LJL7OL7|||F7O||L-JO|LJ|||FJFJFJ|F7O|L7||FJ||F--7LJ|L7F-J|LJ||LJ|L7L7F7|LJL-J|L-7|||FJ|F--JFJOLJOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOL--7L7O||||||FJL7OF-JF-J||L7L-JFJ|L7L7|||L7LJL-7|F7|FJL7OL-7|L-7L7|FJ|||F----JOFJ|||L7LJF7FJF7F7OOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOF7OOF7L7L7|||||LJF7L7|F7L7FJL7|F--JFJFJFJ||L7L-7F-JLJLJL7FJF-7||F7L7LJ|FJ||L---7F7L7LJL-JF7|LJO||||OOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOO||OFJL7L7||LJ|L-7|L-JLJ|FJL-7||L--7L7L7L7||FJF-JL--7F7OO||OL7LJLJL7L-7|L7LJF---J|L7L--7F-JLJF7O|||L7OOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOF7F7FJL-JF7L-JLJF-JF7|L7F7OFJL--7|LJF--JO|FJFJ||L7L7F---J||OFJL7OL--7F-JF7|L-JF-JF--7L7|OF-JL--7O|L-JLJFJOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOFJLJ|L----JL-7F-7L--JLJFJ||FJF---JL-7|F7OFJL7L7||FJFJ|OF7O|L7L7FJF---JL7O||L--7L7O|F-JFJL7L7F---JFJF7F-7L7OOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOL--7|F7F--7F-J|OL-7F--7|FJLJFJF7F7F7|||L7L-7|FJLJ|OL7L7|L7L7|FJL7L----7L7||F-7L7L7||F7L-7L7|L-7F7|FJLJOL7L7OOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOO|LJ|L7FJL-7|F7FJL7FJ|L7F-JO|||||||||FJF-J||F--JF7|FJ|FJFJ||F-JF7F7FJFJ||L7|O|FJ|LJ|F7L7LJF-J||||F-7F7|FJOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOFJF7L-J|F7OLJ||L--JL7L7||OF7|||LJ||LJL7L-7LJL-7O||||FJL7L7LJL7FJ|||L7|O||FJ|FJ|O|F-J||OL-7L7FJ||||FJ||LJF7OOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOL-JL--7|||F7FJ|F7OF7L7LJ|FJ|||L7FJL7F7L-7|F---JFJLJ|L-7|OL7F-JL7LJ|FJL7||L7||FJFJ|F7|L7F7|FJL7LJLJL-J|F-JL7OOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOF7F-JLJ|||L7LJL-J|OL-7|L7LJ|O|L-7LJL-7|||F-7OL--7|F-J|F-J|F7FJF7|L-7|||FJ||L-JFJ|||FJ||||F7|F---7F7|L7F-JOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOF-J|L---7||L7L-7F--JF--JL-JF7|FJF-JF7F7|LJLJFJF7F7|||F7|L-7||||FJLJF7|LJ|L7|L--7|O|LJL7|LJLJ||L--7LJLJFJL--7OOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOL-7L7F--J||FJF7|L7F7L---7F-JLJL7L7FJ|||L7F--JO|||LJ|||LJF-J||LJL7F7|LJF-JFJ|F-7|L-JF7FJL7F--J|F--JF-7FJF---JOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOF-JFJL--7LJL-JLJFJ||F-7O||F--7O|FJ|FJ||FJ|F7F7||L-7||L7FJF-J|F--J||L-7L-7L7|L7||F--JLJOFJ|OF7|L7F7L7||FJOF7F7OOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOL-7|F7F7L------7|FJ||FJFJ|L-7|FJ|FJ|O||L7LJLJ||L-7|LJFJL7L7O||F7O|L-7|F-JO|L-JLJL-7F7F7L7L7|LJFJ|L7|||L-7||||F7OOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOF-JLJ|||F7F7OF7||L7|||FJFJF7|LJFJL7|FJ|FJF---JL-7|L-7L-7L7|FJ||L7L-7LJL--7L---7F--J|||L7|FJ|F-JO|FJ|||F-J||||||OOOOOOOOOOOOOOOO
# OOOOOOOOOOOF7|F--7LJLJ||L7|LJL-JLJ|L7|O||L-7|F7||L7|L7L---7F7|L-7|F-JFJ|L7||FJF7L-7F--JF---JL-7O||L7|||FJL--7|L-JLJ|F-JLJLJL--7OOF7OOOOOOOOO
# OOOOOOOOOOFJ|LJF7L---7|L7||F7F---7|O|L7||F-JLJ|||FJL7|F---J|||F7LJL7FJFJFJ||L7|L7O|L-7OL---7F-JFJL7|||||F---J|F----JL7F-------JOO|L7OOOOOOOO
# OOOOOOOOOOL7L--JL7F--JL7||LJLJF7FJL7L7||||F---J||L-7LJL7OF7||LJL--7LJFJOL7|L7||FJFJF7L-7F7FJL-7|F-J|||||L7F7FJL-7F7OFJL-----7OOOFJFJOOOOOOOO
# OOOOOOOOOOOL----7|L---7LJ|F-7FJ|L-7L-J||LJ|F7F7|L7OL7F-JFJ||L-7F-7|F7L7F7|L7||||FJFJL--J|LJF--J||F7||||L7LJLJF--J|L7L7F--7F-JOF7L7|OOOOOOOOO
# OOOOOOOOOOOF--7O||F--7L-7|L7|L7|F7L7F-JL-7|||||L7|F7||F7L7||F-J|FJLJ|FJ||L7|||||L7|F7OF7L-7|F7O||||||||O|F---JF-7|FJFJ|F7LJOOO|L7|L-7OOOOOOO
# OOOOOOOOOOFJF7L-J||F-JF7||FJL7|LJL-JL7F7FJLJ||L7|||||LJ|FJ|||F7||F7FJ|FJL7||||||FJ||L7||F7|||L7|||||LJ|FJL----JFJ||FJFJ||F7OF7L7LJF-JOOOOOOO
# OOOOOOOF7OL-JL7F7LJL7FJLJLJF7LJF7F--7|||L--7|L7LJ||||F-J| LJ||LJ|||L7|L-7||||||||FJ|FJ|||||LJFJ|||||F7LJ F-----JFJLJFJO|||L7||FJF-JOOOOOOOOO
# OOOOOOFJ|F7F7OLJL7F7LJF7F7FJ|F-JLJF-J|||F7FJL7|F-J|||L7FJF--J|F-J|L7||F7|||LJ||LJ|FJ|FJ|||L-7L7||||LJ|F--JF---7O|F--JF7|||FJ||L7L--7OOOOOOOO
# OOOOOOL7LJLJ|F7F7||L--JLJ|L7LJF-7OL-7||||||F7||L-7||| || L-7FJ|F7| ||||LJ||F-JL-7||FJ|FJ|L7FJFJ|||L7FJL7F-JF-7L7|L7F7||||||FJL-JF--JOOOOOOOO
# OOOOOOOL---7LJ|||LJF----7L-JF7L7L---JLJ|||||LJL-7|||L7LJF--J|FJ|LJFJ||L-7|||F-7FJ||L7|L7|FJ| L-J||FJL7 LJF7L7L-JL7LJLJLJLJLJF7F7L----7OOOOOO
# OOOOOF---7OL-7|||F7L---7L7F7||OL-7F7F7 LJ|||F7F7|LJ|FJF-JF-7|L7L-7|FJ|F7||||L7||FJ|FJL7||L7L---7LJ|F7|F--JL7L----JF--7F7F7F-JLJ|F-7F-JOOOOOO
# OOOOOL--7|F7FJLJLJL--7O|FJ|LJL--7LJLJL-7 LJ|||||L7FJ|FJF7|FJ| L7FJ||FJ||||||FJLJL-JL7FJ|L7L7F-7L-7||||L7F-7|F7F7F7L7FJ|||LJF--7LJOLJF7OOOOOO
# OOOOOOF-JLJLJF--7F--7|FJL7L----7L------JF-7||LJ|FJ|FJL7||||FJF-JL7|||FJLJ|||| F-----JL7|FJFJL7|F7|LJLJ LJFJLJLJLJL-JL-J|L7O|F-JF--7FJL7OF7OO
# OOOOOOL7F---7|F-J|F-JLJF7L7OF7FJF7F7F7 FJFJ|L7FJ|FJ|F-J||||L7|F-7||||L-7FJ||L7L--7F-7FJ|L7L7FJ||LJ F7F-7FJF7F7F7OF----7L7L7||F7|F-J|F-JFJ|OO
# OOOF7OOLJF--J||F-J|F7F7|L7L-JLJFJ||LJL-JFJ L7|L7|L-JL-7|LJ|FJ|L7||||L7FJL-JL7|F--J|FJ|FJFJ || |L7F-JLJFJL-J||LJL-JF---JFJFJ|LJLJL--JL--JFJOO
# OF-JL7OOFJF-7|||F7LJLJ||O|F-7F7|OLJF-7F7|F-7LJ LJF----J|F-JL7|FJ||LJFJL---7 LJL7F-JL7|L7|F-J|FJFJL---7L---7LJF----JF7F7L-JO|F--7F7F7F--7|OOO
# OL-7FJF7|FJFJ|LJ||F7F7LJFJ|OLJLJF-7L7|||LJFJ F7F7L7F-7FJ|F-7|||FJL7 L7F-7FJF--7LJF--J|FJ|L7FJL7|F7F--JF7F7L-7L-7F-7|||L-7F7|L-7LJLJ|L7FJL-7O
# OF-JL-JLJL7L-JOFJLJLJL--JFJF---7L7L-JLJL--JF7|LJ| LJ || |L7||||L7FJF7LJ |L7|F7L--JF7FJL7| |L7 |||LJF7FJLJ|F7L--J|FJ|||F-J|LJF7L7F-7L7|L---JO
# O|F7F7F-7FJF---JF7F7F7F7FJOL--7L-JF---7F7F-JLJF7L---7||FJFJ|||L7|L-JL--7L7|LJ|F7F-J||F-JL7|FJFJ|L--JLJ F7LJL--7O|L7||||F7|F-JL-J|FJO|L7OOOOO
# OLJ||LJFJ|OL--7FJ||LJLJLJF7OF7L--7|F--J|||F---JL7F-7|||L7L7||L7|L7F-7F7L7LJ FJ||| FJ|L-7FJLJFJFJF------JL----7L7L7LJ|||||||F7OF7|L-7|FJOOOOO
# OOOLJOO|FJF7OO||OLJOF7F--JL-J|F7OLJL-7FJLJL---7 LJ ||LJFJFJ|L7LJFJL7|||FJF--JFJ||FJFJF-J|F7FJFJ L7F7F-------7L7L-JF-J|LJLJLJL-J||F-JLJOOOOOO
# OOOOOOOLJFJ|OO||F7F-J|L-----7|||F7OF-J|F------JF7F7LJF-JFJ |FJF-JF-JLJ|L7|F7FJFJ||FJFJF7LJ|L7L-7 LJLJF----7FJFJF7FJF-JF---7F7F7||L-7OOOOOOOO
# OOOOOOOOOL7|F7LJ||L-7L------JLJLJL-JF7|| F7F7F7|LJL-7|F7L-7||FJF7L--7FJFJLJ|L7L7||L7L7||F7L7L--JF7F7 L---7LJOL7|||FJF7L7F7LJLJ|LJF7L7OOOOOOO
# OOOOOOOOF7||||F7|L7OL--------7F--7F-JLJL-JLJLJLJF-7FJLJL7FJLJ|FJ|F-7|L7L-7 |FJFJ|L7| LJLJ|FJF---JLJL--7F7L-7F7LJ|LJFJL7LJL---7L7FJ|FJOOOOOOO
# OOOOOOF7|LJLJ||||FJF7F7F----7|L7FJ|F----7F7F7F--J LJ F--JL--7||FJ| LJ L7FJFJ| L7| ||F----JL7L-----7F-7LJL--J||F7L7FJF7L7F----JOLJOLJF7OOOOOO
# OOOOOFJLJF--7LJ|||FJLJLJF--7LJFJL-JL---7LJ|||L-7 F7F7L-7F7F-J||L7L-7F--JL7L7L-7LJFJ|L---7F7L7F----J|FJF7F---JLJL7|L-JL7|L7F7F7F7F7F-J|OOOOOO
# OOOOOL-7FJF-JF7LJLJF7F7FJOFJF7L7F------JF7LJ|F7L-JLJL7 LJ|L7 LJ L7FJL7F-7| |F7L7 L7|F---J|L-JL--7F-JL-JLJF------JL7F7FJL7LJLJLJLJLJF-JOOOOOO
# OOOOOF7||OL-7|L7F7FJ||||F-JFJL7|L7F7F7F-JL-7LJ|F----7L--7|FJ    FJL-7|| |L7LJ|FJ  LJL7F-7|F-7F7 LJF7F--7 L------7OLJ|L7FJF-7F-7F--7L-7OOOOOO
# OOOF-JLJL7F-J|FJ|LJFJ|LJL-7|OOLJOLJLJLJF---JF7LJF7F7L---J||  F-7|F7FJ|| L-J  LJ    F-JL7LJL7|||F-7|||F7L----7F--JF-7L-J|FJO||FJ|F7L--JOOOOOO
# OOO|F7F--JL--JL-JF7L-JOF--JL7F---7F--7FJF7F7|L--JLJL--7F7LJF7|FJLJ|L7|L7           L-7FJF--J|||L7|||LJL----7|L7F-JFJF7FJL-7||L7LJL--7OOOOOOO
# OOOLJLJOOF7F7F7F7||F7F7L----JL--7|L-7||FJLJLJF---7F-7FJ|| FJLJ|   |FJL7|             LJ L7F7LJL-JLJL-------JL7||F7L-J|L7F-JLJO|F----JOOOOOOO
# OOOOOOOF-J||LJLJLJ|||||F--7OF7F7||OFJ|LJF7F-7L--7|L7LJ |L-JF--J F-JL-7LJ           F--7F7||L7F------------7F-JLJ||F7FJO|L----7||F----7OOOOOO
# OOOOOOOL-7|L---7F7|||||L-7|FJLJLJL7L7|F7||L7L-7FJL7L---JF-7L--7FJF7F7|             L-7LJLJ| LJF-----------JL----JLJLJOFJF---7||LJF7F-JOOOOOO
# OOOOOOOF-JL----J||LJLJL-7||L-7F--7L-J||LJL7L-7|L-7|F-7F-J L7F-JL7|||LJ               L----JF7FJF7F7F7F7F-----------7F7L7L--7LJ|F7|LJOOOOOOOO
# OOOOOOOL-------7|L7F-7F7LJL-7LJF7L-7FJL7F7L--JL7FJ|L7|L-7F-JL7  LJLJ                 F7F7 FJLJFJLJ||LJLJF---------7LJL7|F--JF7LJ|L--7OOOOOOO
# OOOOOOOF-------J|FJ|FJ|L7F-7L--JL7FJL-7LJL---7 LJ L7|L7FJL7F-J                      FJLJL-JF--JF7 ||F--7L--------7L-7FJ|L---JL7OL--7|OOOOOOO
# OOOOOOOL-7F7F7F7|L-J|FJOLJOL---7FJL--7L---7F-JF---7|L7LJ  ||                       FJF-7F7FJF--JL7LJL-7L---------JF7LJOL-7F--7L---7|L7OOOOOO
# OOOOOOOOFJ|LJ||LJF--J|OF7F7F--7|L----JF--7LJF-JF--JL-JF7F7LJ                       L7| LJLJ L---7L7 F7L7F--------7|L----7LJOFJF7F7|L-JOOOOOO
# OOOOOOOOL-JF-J|F7L7F7|FJLJLJF7LJF7F---JF-JF7L-7L7F7 F7|||| F7                      FJ|F-7F7F7 F7L7L7|L7LJF------7LJF7F-7|F-7L-JLJLJOOOOOOOOO
# OOOOOOOF7OOL--J||FJ|LJL---7FJL--J||F---JF7||F-JFJ||FJ||LJL-J|                      L-JL7LJLJL7|L-JFJ|FJF7L-----7|F-JLJFJ||FJF--7F--7OOOOOOOO
# OOOOOOO|L-7F---J|L7|F-----J|F----J||F7F7|||LJF7L-J|L7LJF---7L-7                   F---7L7F7F7|L--7|FJL-JL------JLJF7F7L-J|L-JF7LJF-JOOOOOOOO
# OOOOOF-JF-JL--7FJOLJL7F-7F7|L7F---JLJLJLJLJF7|L7F7L-JF7L--7|F-J                   L--7| ||LJ|L---JLJF------7OF7F--JLJ|F-7|F--JL--JF-7OOOOOOO
# OOOOFJF7|F7F7O||F7OF-J|OLJLJOLJF--7F7F---7FJLJ LJ|F7FJL7F-JLJ                       FJL7LJF-JF-7F7F7|F7 F-7L-JLJF----JL7|||F---7F7|FJOOOOOOO
# OOOOL-J|||LJL-JLJL7L--JF7F-----JF7LJLJ F7|L----7 LJ|L7FJL-7F7                     F7L-7L--JF-J LJ|||||L7L7L7F7F7L--7F7FJLJLJF7FJ|LJ|OOOOOOOO
# OOOOOF-JLJF-7F7F7FJF7F7||L----7FJL-----J|L7F7F-JF7 L-JL-7FJ||                    FJL--JF--7|F7F-7LJLJL7L-JOLJ|||F-7LJLJF7F7FJLJO|F-JOOOOOOOO
# OOOOOL--7FJOLJ|||L-JLJ|||F7F7FJ|F---7F-7L7LJLJF-JL---7F7LJ ||                    L---7FJ FJ|||L7| F7F7L7F--7O|||L7|F---JLJLJF7F-JL--7OOOOOOO
# OOOOOOOO||F--7LJL----7|||||||L-JL--7LJ L-JF---JF7F7F7LJL--7||                    F--7LJF7L-J||FJL-JLJL7LJF7L7LJL-JLJF7F-----J|L7F---JF7OOOOO
# OOOOOOOO||L-7|F7F7F--JLJ|||||OF7F7OL---7F7|F---JLJLJL-----J||F7                  L-7L-7|L7 FJLJF--7F-7L--JL-JOF----7||L7F---7L-JL----J|OOOOO
# OOOOOOOOLJF-JLJLJLJF---7LJLJL-JLJ|F----J|LJL--7F--------7F7||||F7                F7L7FJL7L-JF-7|F-J| L7F-7F7F7|F---J|L-JL--7L7F-------JOOOOO
# OOOOOOOOOOL-7F-7F--JF7OL--7F----7|L-7F-7|F----J|F-------J|||||LJL7            F--JL-J|F7L7F7|FJ||F7|F-JL7LJLJ|||F7F7|F7F7F7L7|L----7OOOOOOOO
# OOOOOOOOOOOFJ|FJ|F--JL---7LJF7F-JL7FJ|FJ|L----7||F7 F7F7 ||||L7F-J            L7F-7F7LJL7LJLJL-JLJLJ|F--JF---J|LJLJLJ|LJLJ|FJL7F7F-JOOOOOOOO
# OOOOOOOOOOOL7|L7|L7F7F7F7L-7||L--7|L7||FJF-7F-J|LJL7|LJL-JLJL7|L7              LJ LJL-7FJ F7F-------J|F--JF7F7|F----7L---7|L7OLJLJOOOOOOOOOO
# OOOOOOOOOOOOLJO|L7LJ||||L-7|||F--JL-J|LJFJFJL--JF-7LJF7F7F-7FJ|FJ     F7         F7F7FJL7FJ|L----7F7FJL---JLJLJL---7L----JL-JF7F7OF7OF7OOOOO
# OOOOOOOOOOOF---JFJOFJ||L7FJLJLJF7F---JF-J L7F-7FJ L7FJ|||L7||FJL--7   |L7   F7 F7||||L-7|L7|F-7F7LJLJF-----7F7F7F--JF7OF7F7F7|LJL-JL-JL7OOOO
# OOOOOOOOOOOL----JF7L-JL-JL--7F-J||OF--JF7F7|L7|L-7 LJFJ||FJLJL7F--JF--JFJ   || |LJLJL-7||FJ|L7||| F7 L----7|||||L---JL-JLJLJLJF--------JOOOO
# OOOOOOOOOOOF-----JL-7F7F7OF-JL-7||FJF--JLJ|L-JL--J F7L-J|L-7F-JL--7L7F-JF7 FJL7L---7F7|||L7|FJ|||FJ|F7F-7FJLJLJ|F----7F----7F7|OF7F-7OOOOOOO
# OOOOOOOOOOOL-------7|||||FJF-7FJLJL-JF----JF--7 F7FJ|F-7L-7|L--7F-JFJ|F7|L7|F-JF-7 LJ|LJL-JLJFJ||L7|||L7LJF7F7FJL---7||F7F7|||L-JLJFJOOOOOOO
# OOOOOOOOOOOOOF7F7F7|LJLJLJFJFJL7F----JF7F--JF-JFJ||FJ|FJF7LJF7FJL7 L7|||L7||| FJFJF--JF---7F7L-JL-JLJL-JF-JLJ||F7F--JLJ|LJ|LJL7F--7|OOOOOOOO
# OOOOOOOOOOOOFJLJLJ|L7F7F-7|FJF-JL----7||L7F7L7 L7LJL-JL-JL7FJ|L7FJF7|LJL-J|||FJFJ L-7FJF7FJ||F-7F7F7F7F7|F---JLJ|L-----JF7L-7FJ|F7||OOOOOOOO
# OOOOOOOOOOOOL-7F-7L7||||OLJL-JF7OF7F7LJL7||L-JF7|F7F------JL7|FJL7||L----7LJLJFJ  F7LJ ||L7|LJ ||LJLJLJLJL----7OL------7||F7|L7LJ|LJOOOOOOOO
# OOOOOOOOOOOOOFJL7L7LJ|LJF--7OFJL-JLJL7F7LJL-7FJLJ|LJF--7F7 FJ|L7FJ||F---7|F---JF7FJ| F7|| LJF-7LJ F-----7F----JF------7|||||L7|F7|OOOOOOOOOO
# OOOOOOOOOOOOFJF7L7L--JF7L-7L7L-----7 LJL7F-7LJF7FJF7|F-J|L7L7|FJL7||L7F-J|L7F--J|L7L7||||F-7L7| F7L----7|L-----JF-----JLJLJ|FJ||||OOOOOOOOOO
# OOOOOOOOOOF-JFJL7|F---J|F7L7L-7F7F7L---7LJFJF-J|L-J||L-7L7| ||L-7LJ|FJ|F7L7LJF7FJ L7LJLJ|L7|FJL-J|F7 F-JL--7F7F7L-----7F7F7||FJ|LJOOOOOOOOOO
# OOOOOOOOOO|F7|OOLJL-7F7||L-JF7LJLJL----JF7L7|F7L7F-JL7FJFJL7||F7|F-J|FJ||FJF-JLJ   L7F-7L7||L7F-7LJL7L---7OLJLJL------J||||LJL-JOOOOOOOOOOOO
# OOOOOOOOOOLJLJOF7OF7LJ|LJF7FJL7F7F-7F7F-JL7|LJL7||F--JL7L7FJ|LJLJL-7||FJ||FJF7 F7 F7LJFJFJ||FJL7L7F7| F7 L---7OF---7F7FJLJL7F-7OOOOOOOOOOOOO
# OOOOOOOOOOOOF--J|FJL--JF7||L7OLJLJFJ|LJF7FJL---J||L---7L-J| L-7F---J||L7||L7|L7||FJ|F7L7|FJ|L7FJ LJ|L-JL----7L-JF--J|LJF7F7LJFJOOOOOOOOOOOOO
# OOOOOOOOOOOOL--7LJF--7FJLJL-JF7OF7L-JF-J|L--7 F7LJ F7 L--7L--7||F-7 ||FJ|L7||FJ|||FJ||FJ|L7| LJ F7FJF7F7F--7L---JF7O|F-JLJL--JF7OOOOOOOOOOOO
# OOOOOOOOOOOOOOO|F7|F-JL7F----JL-JL--7|F7L---JFJL7F7||F--7|F7FJ||L7L7||L7|FJ||L7|||L7|LJFJFJL7F7FJ|L7|LJLJF-JOF--7|L-JL----7F--JL-7OOOOOOOOOO
# OOOOOOOOOOOOOOFJ||||F--JL-------7F-7LJ|| F7 FJF7LJ|||L-7|LJ|L7|| L7LJ| |||FJL7|||L7|L7FJ L7FJ||L7L7||F---JOF-JF-J|F---7F7FJ|F----JOOOOOOOOOO
# OOOOOOOOOOOOOFJFJLJLJF----------J|FJ FJ|FJL7|FJL--J|L7FJ|F-JFJ||F7|F-JFJ||L7FJ|||FJL-JL7F7|L7|L-JFJLJL-----JF-JF-JL7F7LJLJO||F7OOOOOOOOOOOOO
# OOOOOOOOOOOOOL-JF--7FJF7F7F------JL-7L7|L7FJ||  F7 L7|L7||F7L-J||LJL-7L7||FJL7|||L--7F7LJ|L7|L7F7|F7F7F-7F--JOFJF-7LJ|F7F7O|LJL-7OOOOOOOOOOO
# OOOOOOOOOOOOOF7OL-7|L7|LJLJOF--7OF7FJFJL-J|FJL7FJL7FJ|FJ|LJL7F-JL-7F7|FJ|||F7|LJL7F7LJL7FJFJL7||LJ|||||FJL----JFJFJF7LJLJL-JF--7|OOOOOOOOOOO
# OOOOOOOOOOOF7||OF7||O||F----JF7L-JLJ L7F--JL-7||F-JL7||FJF7FJL7 F7||LJ|FJ||||L-7FJ||F7FJL7|F7LJL-7|||||L7F-7F-7|OL-JL7F-7F-7L-7||OOOOOOOOOOO
# OOOOOOOOOOFJLJL-J||L7LJL--7F-JL7F---7FJ|F-7F-J||L7F7|LJ|FJ|L-7L7|||L7FJ|FJ||L-7|L7|||||F-JLJL7F--J||||L7||OLJO|L---7FJL7|L7L--JLJOOOOOOOOOOO
# OOOOOOOOOOL7F7F-7|L7L7F7F-J|F7OLJF--J|FJL7|L-7||FJ||L-7|L7|F7|FJ||L7|L7|L7||F-J|FJ||||||F7 F7|| F7|||| ||L---7|F--7|L7FJL-JOF7F--7OOOOOOOOOO
# OOOOOOOOOOOLJLJFJ|OL7LJ|L--J||F--JF7FJ|F7||F-J|||FJL7FJL7|||LJ|FJ|FJL7||FJ||L-7|L7|||LJ||L7|||L7|LJ||L7||F--7|||F7LJO|L--7F-JLJF7|OOOOOOOOOO
# OOOOOOOOOOOOOF7L7L7OL-7|OF-7||L--7||L7||LJ|L7FJ|||F-JL7O||||F-JL7|L-7||||FJ|OFJ|OLJ|L7FJL7|||L7|L-7||FJ||L-7LJLJ|L-7FJF7FJ|F---J||OOOOOOOOOO
# OOOOOOOOOOOF-JL-JFJF7FJL7L7|||F7O||L-JLJF-JFJL7|LJL--7L7||LJL7F7|L7FJ||LJL7|FJFJF7O|FJ|F7|LJL7|L7FJLJL7||F7L--7FJF7||FJ|L7|L---7LJOOOOOOOOOO
# OOOOOOOOOOOL7F--7L-JLJF7L-JLJLJL-JL--7F-JF7|F7|L---7FJFJLJOF7|||L7LJFJL-7FJ|L7|FJL-JL7LJ|L7F-J|O|L7F--J||||F-7LJFJLJLJOL7LJF7F7|OOOOOOOOOOOO
# OOOOOOOOOOOOLJF7|F7F7FJL-----7F--7F7FJ|F7||LJ||F7F-JL7L--7FJLJ|L7L7OL7F-J|FJFJ|L--7F7L-7L-JL-7L7L7||F-7|LJLJO|F-JF7F7F7FJF7|||LJOOOOOOOOOOOO
# OOOOOOOOOOOOF7||LJLJLJF------J|F7||LJO|||||F7|||LJOF7L7F-J|F7FJOL7L-7|L-7|L7L7|OF-J||F7|F----JFJO||||FJL7F7F7LJF7|LJ|||L-JLJLJOOOOOOOOOOOOOO
# OOOOOOOOOOF7|LJ|OF7OF7L7F-7F-7||LJL--7|||||||||L7F-JL-JL-7|||L7OFJF7|L7FJL7L7||FJF7|||LJL-7F-7L-7LJ||L-7LJ|||F-JLJF7LJL-------7OOOOOOOOOOOOO
# OOOOOOOOOFJLJF7L-J|FJL-J|O||FJ||F7F7FJ||||||LJL-JL----7F-J||L7L7L-JLJFJL-7L-J||L7||||L7F-7||FJF7|F-JL7FJF7LJLJF7F7|L7F7F7F7F--JOOOOOOOOOOOOO
# OOOOOOOOOL7F7||F-7LJF7F7|FJ|L7|LJ||LJO||||||F---7F7F--JL-7LJOL7L----7L7F7L7F-J|FJ|LJL7LJFJ||L7|LJ|F7FJ|FJ|F7F-JLJLJFJ|LJ|||L7OOOOOOOOOOOOOOO
# OOOOOOOOOOLJLJ|L7L-7|LJLJL7L7LJF7|L--7LJ||LJL7F7LJLJF7F-7L-7F-JF-7F7L7|||FJL7FJ|FJOF-JF7L7||O||OFJ|||FJL7|||L--7OF7L7|F7LJL7L7OOOOOOOOOOOOOO
# OOOOOOOOOOOOF-JFJF-J|F7F-7L-JOFJLJF-7L-7LJOF-J||F7F7||L7L7FJL-7L7LJ|FJLJLJF-J|FJ|F-JF7||FJLJFJL7L7|LJL-7|LJL7F7L-JL7|LJL--7|FJOOOOOOOOOOOOOO
# OOOOOOOOOOOO|F-JOL7FJ||L7L----JF-7L7L7FJF-7L-7|||||||L7L7||F--JFJOFJ|F7F7FJF-JL7|L7FJ|||L--7L7FJFJL-7F-JL--7||L7F-7||F----J||OOOOOOOOOOOOOOO
# OOOOOOOOOOOO||OOF-JL7|L-JF--7F7|OL7L7|L7L7L--J|LJ||LJFJFJLJ|F-7L-7L7LJLJ|L7L-7FJ|FJL7LJ|F--JFJL7L7F7|L7F7F-JLJFJL7LJLJF--7OLJOOOOOOOOOOOOOOO
# OOOOOOOOOOOOLJF-JF7FJL--7|F-J|LJF-JFJL-JOL7F7FJF-JL7O|FJOF-J|FJF-JO|F7F7L7|F7|L7|L-7|F-JL--7|F7L7||||FJ||L---7L-7L7F--JF-JOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOL-7|||F---J|L-7|OFJF7L---7OFJ|||OL7F7|FJL-7|F7|L7L--7||LJ|FJ||||FJL7O|||F7F7FJLJL-JLJ||L7|L--7FJF-JFJ|F--JOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOFJ|LJL7F7FJF-J|FJFJ|F7F7L7L-JLJF-J|LJ|F7FJ||||FJF7FJ|L7OLJFJ|LJL-7L7||LJ|||L--7OF--7||O|L-7OLJOL-7|O|L7F7OOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOO|FJF--J||L7L7FJ|FJFJ|LJL7L-7OF-JF7L7O||||OLJ||L7|LJFJFJF7OL7|F---JFJ|L-7||L7F7|FJF7LJL7|F7L7OF-7FJL-JFJ|L-7F7OOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOFJL7L---JL7|FJ|FJ|OL7L7F7|F7|FJF7|L7L7||||F-7LJFJL-7L7L-JL-7LJL-7F7L7L--J|L7||LJL7|L7F7|LJL7L7L7||F7F7L-JF7LJ|OOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOL--JOF--7OLJ|FJL7|F7L7LJ|||LJL7|||FJFJLJ|LJFJF-JF7FJOL7F7F-JOF7FJ||FJF---JFJLJF-7LJOLJ|L7F7L7L7||LJLJL7F7|L--JOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOL-7L-7FJL7O|||L-JF-J|L-7FJ|LJL7|F7FJF7L7L-7||L-7FJ||L---J|L7|LJOL7F7FJOF7L7L-7F--JFJ|L7L7LJL--7OFJ||L7OOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOF7L-7LJF7|FJ||F-7|F7|F7|L-JF--JLJ|L7||FJF-J||F7||FJ|F----JFJL--7FJ||L--J|FJF7LJF-7L-JFJFJF7F7FJFJFJ|FJOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOF-JL--JF7||||FJ||FJLJ|||LJF--JF7F7FJO|||L7|F7|||LJ||O|L---7O|F-7FJL-J|F-7FJ|FJL-7|O|F7FJOL7|LJLJOL-JOLJOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOL--7F7FJ||||LJFJ|L7F7||L-7L7F7|||||F-J|L-J|||||L-7||FJF7F7|FJ|OLJF-7FJ|O|L7||F7FJ|FJ||L7F-JL-7F7F7OOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOO||||O||LJF-JFJFJ|LJL--JOLJ|||||||F7L--7||||L7FJ|||FJLJ||L7L---JFJL7|FJFJLJ|LJFJ|FJ|FJ|F7F-J||||F7OOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOFJ|LJOLJOOL7FJOL7L-------7FJ|LJ||LJ|F7FJ||LJFJL7|||L-7FJL7L-7F--JOOLJL7|OOFJF7L7|L7LJOLJ||OFJLJLJL-7OOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOO|FJOOOOOOOFJ|F7O|F7F-7F7FJL7|F-JL7O||||O|L-7L7FJ|||F-JL7FJF-JL---7OOF-JL-7L7|L7|L7L---7O|L-JF7F----JOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOLJOOOOOOOO|FJ|L-J|||OLJ||OOLJL7F7L7LJ|L7L--JFJL7LJLJOOFJL7L-7F-7FJOO|F-7FJFJ|O|L7L7F-7L7L7F-J|L--7OOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJOL-7FJLJOOOLJOOF--J|L7L-7L7L---7|F7|OOOOOOL--JOFJL7LJOOOLJOLJOL7L7L-JFJL7L7|FJL7OL7F-JOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJOOOOOOOOOOL--7|FJF-JO|F7F-JLJLJOOOOOOOOOOOL7FJOOOOOOOOOOOO|FJOOOL7FJO|||F7L7FJL---7OOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO||L7|OOOLJLJOOOOOOOOOOOOOOOOOO|L-7OOOOOOOOOOOLJOOOOO||F-J|LJ|FJ|F7F--JOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJO|L-7OOOOOOOOOOOOOOOOOOOOOOO|F-JOOOOOOOOOOOOOOOOOOLJL7FJOOLJOLJ||OOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL--JOOOOOOOOOOOOOOOOOOOOOOOLJOOOOOOOOOOOOOOOOOOOOOOO||OOOOOOOOLJOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
